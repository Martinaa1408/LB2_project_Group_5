# %% [markdown]
# # Data Collection
#
# ## Selection criteria
# From *UniProt* select the Positive and Negative data following this criteria:
#
# > - **Both sets:** protein evidence, protein length, reviewed status, only eukaryotes, no fragments
# > - **Positive set:** experimental evidence of signal peptide
# > - **Negative set:** no signal peptide (any evidence) + experimental evidence for non-SP compartments
#
# This pipeline retrieves protein data from the UniProt database using its REST API and filters positive entries for the existance of a cleavage site and signal peptide (SP) length over 14 residues.
#
# The results are finally saved into TSV and FASTA files, reporting following information:
#
# ## Output files
#
# We exported the datasets in **two formats**:
#
# > - **FASTA files** contain only the amino acid sequences of the selected proteins.
# > - **TSV files** contain metadata associated with each protein entry.
#
# ### .TSV files content
#
# **Positive dataset**
#  1. UniProt accession
#  2. Organism name
# 3. Eukaryotic kingdom (Metazoa, Fungi, Plants, Other)
# 4. Protein length
# 5. Position of the signal peptide cleavage site
#
# **Negative dataset**
# 1. UniProt accession
# 2. Organism name
# 3. Eukaryotic kingdom (Metazoa, Fungi, Plants, Other)
# 4. Protein length
# 5. Presence of a transmembrane helix in the first 90 residues (True/False)

# %%
# imports and setup
import requests   # to query UniProt REST API
from requests.adapters import HTTPAdapter, Retry   # to handle failed requests
import json     # To parse and handle data in JSON format from API responses
import re      # To use regular expressions to find patterns in text

# %%
url_positive = "https://rest.uniprot.org/uniprotkb/search?format=json&query=%28%28fragment%3Afalse%29+AND+%28taxonomy_id%3A2759%29+AND+%28length%3A%5B40+TO+*%5D%29+AND+%28reviewed%3Atrue%29+AND+%28existence%3A1%29+AND+%28ft_signal_exp%3A*%29%29&size=500"
url_negative = "https://rest.uniprot.org/uniprotkb/search?format=json&query=%28%28reviewed%3Atrue%29+AND+%28fragment%3Afalse%29+AND+%28taxonomy_id%3A2759%29+AND+%28length%3A%5B40+TO+*%5D%29+AND+%28existence%3A1%29+NOT+%28ft_signal%3A*%29+OR+%28cc_scl_term_exp%3ASL-0191%29+OR+%28cc_scl_term_exp%3ASL-0204%29+OR+%28cc_scl_term_exp%3ASL-0039%29+OR+%28cc_scl_term_exp%3ASL-0091%29+OR+%28cc_scl_term_exp%3ASL-0209%29+OR+%28cc_scl_term_exp%3ASL-0173%29%29&size=500"
col_positive = ["Accession", "Organism", "Kingdom", "Sequence length", "SP cleavage"]
col_negative = ["Accession", "Organism", "Kingdom", "Sequence length", "N-term transmembrane"]

# %%
def get_next_link(headers):
  """
  get_batch function take the REST API from UniProt and extracts all the information for the entries.
  """

  # Extract the next page URL from the "Link" header (if present)
  if "Link" in headers:

     # Use the expression re_next_link that matches the "next" URL
      match = re_next_link.match(headers["Link"])
      if match:
          return match.group(1)

def get_batch(batch_url):
  """
  The function get_next_link reads the output of get_batch and, if a link statement is present in the headers, extracts the next link.
  """

  # Retrieve information from the batch_url
  while batch_url:
        response = session.get(batch_url)

        # Stop execution if the request failed (status !=200)
        response.raise_for_status()

        # Get the total number of entries in the search
        total = response.headers["x-total-results"]
        yield response, total

        # Update with the next URL (from the Link)
        batch_url = get_next_link(response.headers)
        print(batch_url)

# %%
# Finds the URL for the next page in the dataset in a response header
re_next_link = re.compile(r'<(.+)>; rel="next"')

# Manages failed requests, it will try the request up to five times before failing
retries = Retry(total=5, backoff_factor=0.25, status_forcelist=[500, 502, 503, 504])

# To handle multiple requests efficiently
session = requests.Session()

# Applies the retry logic defined by retries to the session
session.mount("https://", HTTPAdapter(max_retries=retries))

# %%
get_batch(url_positive)

# Look at the JSON architecture of only the first protein
for response, total in get_batch(url_positive):
  data = response.json()

  entries = data["results"]
  if entries:
    # use the first entry
    first_entry = entries[0]

    # look only the features
    features = first_entry["features"]
    print(json.dumps(features, indent=2))
  break
# Out:
# [
#   {
#     "type": "Signal",
#     "location": {
#       "start": {
#         "value": 1,
#         "modifier": "EXACT"
#       },
#       "end": {
#         "value": 21,
#         "modifier": "EXACT"
#       }
#     },
#     "description": "",
#     "evidences": [
#       {
#         "evidenceCode": "ECO:0000269",
#         "source": "PubMed",
#         "id": "15340161"
#       },
#       {
#         "evidenceCode": "ECO:0000269",
#         "source": "PubMed",
#         "id": "9571159"
#       }
#     ]
#   },
#   {
#     "type": "Chain",
#     "location": {
#       "start": {
#         "value": 22,
#         "modifier": "EXACT"
#       },
#       "end": {
#         "value": 401,
#         "modifier": "EXACT"
#       }
#     },
#     "description": "Tumor necrosis factor receptor superfamily member 11B",
#     "featureId": "PRO_0000034587"
#   },
#   {
#     "type": "Repeat",
#     "location": {
#       "start": {
#         "value": 24,
#         "modifier": "EXACT"
#       },
#       "end": {
#         "value": 62,
#         "modifier": "EXACT"
#       }
#     },
#     "description": "TNFR-Cys 1"
#   },
#   {
#     "type": "Repeat",
#     "location": {
#       "start": {
#         "value": 65,
#         "modifier": "EXACT"
#       },
#       "end": {
#         "value": 105,
#         "modifier": "EXACT"
#       }
#     },
#     "description": "TNFR-Cys 2"
#   },
#   {
#     "type": "Repeat",
#     "location": {
#       "start": {
#         "value": 107,
#         "modifier": "EXACT"
#       },
#       "end": {
#         "value": 142,
#         "modifier": "EXACT"
#       }
#     },
#     "description": "TNFR-Cys 3"
#   },
#   {
#     "type": "Repeat",
#     "location": {
#       "start": {
#         "value": 145,
#         "modifier": "EXACT"
#       },
#       "end": {
#         "value": 185,
#         "modifier": "EXACT"
#       }
#     },
#     "description": "TNFR-Cys 4"
#   },
#   {
#     "type": "Domain",
#     "location": {
#       "start": {
#         "value": 198,
#         "modifier": "EXACT"
#       },
#       "end": {
#         "value": 269,
#         "modifier": "EXACT"
#       }
#     },
#     "description": "Death 1"
#   },
#   {
#     "type": "Domain",
#     "location": {
#       "start": {
#         "value": 270,
#         "modifier": "EXACT"
#       },
#       "end": {
#         "value": 365,
#         "modifier": "EXACT"
#       }
#     },
#     "description": "Death 2"
#   },
#   {
#     "type": "Site",
#     "location": {
#       "start": {
#         "value": 400,
#         "modifier": "EXACT"
#       },
#       "end": {
#         "value": 400,
#         "modifier": "EXACT"
#       }
#     },
#     "description": "Involved in dimerization"
#   },
#   {
#     "type": "Glycosylation",
#     "location": {
#       "start": {
#         "value": 98,
#         "modifier": "EXACT"
#       },
#       "end": {
#         "value": 98,
#         "modifier": "EXACT"
#       }
#     },
#     "description": "N-linked (GlcNAc...) asparagine",
#     "evidences": [
#       {
#         "evidenceCode": "ECO:0000255"
#       }
#     ],
#     "featureId": ""
#   },
#   {
#     "type": "Glycosylation",
#     "location": {
#       "start": {
#         "value": 152,
#         "modifier": "EXACT"
#       },
#       "end": {
#         "value": 152,
#         "modifier": "EXACT"
#       }
#     },
#     "description": "N-linked (GlcNAc...) asparagine",
#     "evidences": [
#       {
#         "evidenceCode": "ECO:0000255"
#       }
#     ],
#     "featureId": ""
#   },
#   {
#     "type": "Glycosylation",
#     "location": {
#       "start": {
#         "value": 165,
#         "modifier": "EXACT"
#       },
#       "end": {
#         "value": 165,
#         "modifier": "EXACT"
#       }
#     },
#     "description": "N-linked (GlcNAc...) asparagine",
#     "evidences": [
#       {
#         "evidenceCode": "ECO:0000255"
#       }
#     ],
#     "featureId": ""
#   },
#   {
#     "type": "Glycosylation",
#     "location": {
#       "start": {
#         "value": 178,
#         "modifier": "EXACT"
#       },
#       "end": {
#         "value": 178,
#         "modifier": "EXACT"
#       }
#     },
#     "description": "N-linked (GlcNAc...) asparagine",
#     "evidences": [
#       {
#         "evidenceCode": "ECO:0000269",
#         "source": "PubMed",
#         "id": "22664871"
#       }
#     ],
#     "featureId": ""
#   },
#   {
#     "type": "Glycosylation",
#     "location": {
#       "start": {
#         "value": 289,
#         "modifier": "EXACT"
#       },
#       "end": {
#         "value": 289,
#         "modifier": "EXACT"
#       }
#     },
#     "description": "N-linked (GlcNAc...) asparagine",
#     "evidences": [
#       {
#         "evidenceCode": "ECO:0000255"
#       }
#     ],
#     "featureId": ""
#   },
#   {
#     "type": "Disulfide bond",
#     "location": {
#       "start": {
#         "value": 41,
#         "modifier": "EXACT"
#       },
#       "end": {
#         "value": 54,
#         "modifier": "EXACT"
#       }
#     },
#     "description": "",
#     "evidences": [
#       {
#         "evidenceCode": "ECO:0000255",
#         "source": "PROSITE-ProRule",
#         "id": "PRU00206"
#       },
#       {
#         "evidenceCode": "ECO:0000269",
#         "source": "PubMed",
#         "id": "22664871"
#       }
#     ]
#   },
#   {
#     "type": "Disulfide bond",
#     "location": {
#       "start": {
#         "value": 44,
#         "modifier": "EXACT"
#       },
#       "end": {
#         "value": 62,
#         "modifier": "EXACT"
#       }
#     },
#     "description": "",
#     "evidences": [
#       {
#         "evidenceCode": "ECO:0000255",
#         "source": "PROSITE-ProRule",
#         "id": "PRU00206"
#       },
#       {
#         "evidenceCode": "ECO:0000269",
#         "source": "PubMed",
#         "id": "22664871"
#       }
#     ]
#   },
#   {
#     "type": "Disulfide bond",
#     "location": {
#       "start": {
#         "value": 65,
#         "modifier": "EXACT"
#       },
#       "end": {
#         "value": 80,
#         "modifier": "EXACT"
#       }
#     },
#     "description": "",
#     "evidences": [
#       {
#         "evidenceCode": "ECO:0000255",
#         "source": "PROSITE-ProRule",
#         "id": "PRU00206"
#       },
#       {
#         "evidenceCode": "ECO:0000269",
#         "source": "PubMed",
#         "id": "22664871"
#       }
#     ]
#   },
#   {
#     "type": "Disulfide bond",
#     "location": {
#       "start": {
#         "value": 83,
#         "modifier": "EXACT"
#       },
#       "end": {
#         "value": 97,
#         "modifier": "EXACT"
#       }
#     },
#     "description": "",
#     "evidences": [
#       {
#         "evidenceCode": "ECO:0000255",
#         "source": "PROSITE-ProRule",
#         "id": "PRU00206"
#       },
#       {
#         "evidenceCode": "ECO:0000269",
#         "source": "PubMed",
#         "id": "22664871"
#       }
#     ]
#   },
#   {
#     "type": "Disulfide bond",
#     "location": {
#       "start": {
#         "value": 87,
#         "modifier": "EXACT"
#       },
#       "end": {
#         "value": 105,
#         "modifier": "EXACT"
#       }
#     },
#     "description": "",
#     "evidences": [
#       {
#         "evidenceCode": "ECO:0000255",
#         "source": "PROSITE-ProRule",
#         "id": "PRU00206"
#       },
#       {
#         "evidenceCode": "ECO:0000269",
#         "source": "PubMed",
#         "id": "22664871"
#       }
#     ]
#   },
#   {
#     "type": "Disulfide bond",
#     "location": {
#       "start": {
#         "value": 107,
#         "modifier": "EXACT"
#       },
#       "end": {
#         "value": 118,
#         "modifier": "EXACT"
#       }
#     },
#     "description": "",
#     "evidences": [
#       {
#         "evidenceCode": "ECO:0000255",
#         "source": "PROSITE-ProRule",
#         "id": "PRU00206"
#       },
#       {
#         "evidenceCode": "ECO:0000269",
#         "source": "PubMed",
#         "id": "22664871"
#       }
#     ]
#   },
#   {
#     "type": "Disulfide bond",
#     "location": {
#       "start": {
#         "value": 124,
#         "modifier": "EXACT"
#       },
#       "end": {
#         "value": 142,
#         "modifier": "EXACT"
#       }
#     },
#     "description": "",
#     "evidences": [
#       {
#         "evidenceCode": "ECO:0000255",
#         "source": "PROSITE-ProRule",
#         "id": "PRU00206"
#       },
#       {
#         "evidenceCode": "ECO:0000269",
#         "source": "PubMed",
#         "id": "22664871"
#       }
#     ]
#   },
#   {
#     "type": "Disulfide bond",
#     "location": {
#       "start": {
#         "value": 145,
#         "modifier": "EXACT"
#       },
#       "end": {
#         "value": 160,
#         "modifier": "EXACT"
#       }
#     },
#     "description": "",
#     "evidences": [
#       {
#         "evidenceCode": "ECO:0000255",
#         "source": "PROSITE-ProRule",
#         "id": "PRU00206"
#       },
#       {
#         "evidenceCode": "ECO:0000269",
#         "source": "PubMed",
#         "id": "22664871"
#       }
#     ]
#   },
#   {
#     "type": "Disulfide bond",
#     "location": {
#       "start": {
#         "value": 166,
#         "modifier": "EXACT"
#       },
#       "end": {
#         "value": 185,
#         "modifier": "EXACT"
#       }
#     },
#     "description": "",
#     "evidences": [
#       {
#         "evidenceCode": "ECO:0000255",
#         "source": "PROSITE-ProRule",
#         "id": "PRU00206"
#       },
#       {
#         "evidenceCode": "ECO:0000269",
#         "source": "PubMed",
#         "id": "22664871"
#       }
#     ]
#   },
#   {
#     "type": "Natural variant",
#     "location": {
#       "start": {
#         "value": 3,
#         "modifier": "EXACT"
#       },
#       "end": {
#         "value": 3,
#         "modifier": "EXACT"
#       }
#     },
#     "description": "in dbSNP:rs2073618",
#     "featureCrossReferences": [
#       {
#         "database": "dbSNP",
#         "id": "rs2073618"
#       }
#     ],
#     "evidences": [
#       {
#         "evidenceCode": "ECO:0000269",
#         "source": "PubMed",
#         "id": "14702039"
#       },
#       {
#         "evidenceCode": "ECO:0000269",
#         "source": "PubMed",
#         "id": "9108485"
#       },
#       {
#         "evidenceCode": "ECO:0000269",
#         "source": "PubMed",
#         "id": "9492069"
#       },
#       {
#         "evidenceCode": "ECO:0000269",
#         "source": "PubMed",
#         "id": "9688283"
#       },
#       {
#         "evidenceCode": "ECO:0000269",
#         "source": "Reference",
#         "id": "Ref.6"
#       }
#     ],
#     "featureId": "VAR_013439",
#     "alternativeSequence": {
#       "originalSequence": "N",
#       "alternativeSequences": [
#         "K"
#       ]
#     }
#   },
#   {
#     "type": "Natural variant",
#     "location": {
#       "start": {
#         "value": 104,
#         "modifier": "EXACT"
#       },
#       "end": {
#         "value": 104,
#         "modifier": "EXACT"
#       }
#     },
#     "description": "in dbSNP:rs11573906",
#     "featureCrossReferences": [
#       {
#         "database": "dbSNP",
#         "id": "rs11573906"
#       }
#     ],
#     "evidences": [
#       {
#         "evidenceCode": "ECO:0000269",
#         "source": "Reference",
#         "id": "Ref.6"
#       }
#     ],
#     "featureId": "VAR_018957",
#     "alternativeSequence": {
#       "originalSequence": "V",
#       "alternativeSequences": [
#         "M"
#       ]
#     }
#   },
#   {
#     "type": "Natural variant",
#     "location": {
#       "start": {
#         "value": 182,
#         "modifier": "EXACT"
#       },
#       "end": {
#         "value": 182,
#         "modifier": "EXACT"
#       }
#     },
#     "description": "in PDB5; dbSNP:rs796051868",
#     "featureCrossReferences": [
#       {
#         "database": "dbSNP",
#         "id": "rs796051868"
#       }
#     ],
#     "evidences": [
#       {
#         "evidenceCode": "ECO:0000269",
#         "source": "PubMed",
#         "id": "12189164"
#       }
#     ],
#     "featureId": "VAR_019413",
#     "alternativeSequence": {}
#   },
#   {
#     "type": "Mutagenesis",
#     "location": {
#       "start": {
#         "value": 78,
#         "modifier": "EXACT"
#       },
#       "end": {
#         "value": 79,
#         "modifier": "EXACT"
#       }
#     },
#     "description": "Decreases inhibition of osteoclast differentiation.",
#     "evidences": [
#       {
#         "evidenceCode": "ECO:0000269",
#         "source": "PubMed",
#         "id": "22664871"
#       }
#     ],
#     "alternativeSequence": {
#       "originalSequence": "DE",
#       "alternativeSequences": [
#         "AA"
#       ]
#     }
#   },
#   {
#     "type": "Mutagenesis",
#     "location": {
#       "start": {
#         "value": 116,
#         "modifier": "EXACT"
#       },
#       "end": {
#         "value": 116,
#         "modifier": "EXACT"
#       }
#     },
#     "description": "Reduces affinity for TNFSF11. Decreases inhibition of osteoclast differentiation.",
#     "evidences": [
#       {
#         "evidenceCode": "ECO:0000269",
#         "source": "PubMed",
#         "id": "22664871"
#       }
#     ],
#     "alternativeSequence": {
#       "originalSequence": "E",
#       "alternativeSequences": [
#         "A"
#       ]
#     }
#   },
#   {
#     "type": "Mutagenesis",
#     "location": {
#       "start": {
#         "value": 400,
#         "modifier": "EXACT"
#       },
#       "end": {
#         "value": 401,
#         "modifier": "EXACT"
#       }
#     },
#     "description": "Abolishes dimerization.",
#     "alternativeSequence": {}
#   },
#   {
#     "type": "Mutagenesis",
#     "location": {
#       "start": {
#         "value": 400,
#         "modifier": "EXACT"
#       },
#       "end": {
#         "value": 400,
#         "modifier": "EXACT"
#       }
#     },
#     "description": "Abolishes dimerization.",
#     "evidences": [
#       {
#         "evidenceCode": "ECO:0000269",
#         "source": "PubMed",
#         "id": "9478964"
#       }
#     ],
#     "alternativeSequence": {
#       "originalSequence": "C",
#       "alternativeSequences": [
#         "S"
#       ]
#     }
#   },
#   {
#     "type": "Sequence conflict",
#     "location": {
#       "start": {
#         "value": 263,
#         "modifier": "EXACT"
#       },
#       "end": {
#         "value": 263,
#         "modifier": "EXACT"
#       }
#     },
#     "description": "in Ref. 1; AAB53709",
#     "evidences": [
#       {
#         "evidenceCode": "ECO:0000305"
#       }
#     ],
#     "alternativeSequence": {
#       "originalSequence": "D",
#       "alternativeSequences": [
#         "A"
#       ]
#     }
#   },
#   {
#     "type": "Beta strand",
#     "location": {
#       "start": {
#         "value": 29,
#         "modifier": "EXACT"
#       },
#       "end": {
#         "value": 31,
#         "modifier": "EXACT"
#       }
#     },
#     "description": "",
#     "evidences": [
#       {
#         "evidenceCode": "ECO:0007829",
#         "source": "PDB",
#         "id": "3URF"
#       }
#     ]
#   },
#   {
#     "type": "Beta strand",
#     "location": {
#       "start": {
#         "value": 35,
#         "modifier": "EXACT"
#       },
#       "end": {
#         "value": 37,
#         "modifier": "EXACT"
#       }
#     },
#     "description": "",
#     "evidences": [
#       {
#         "evidenceCode": "ECO:0007829",
#         "source": "PDB",
#         "id": "3URF"
#       }
#     ]
#   },
#   {
#     "type": "Beta strand",
#     "location": {
#       "start": {
#         "value": 40,
#         "modifier": "EXACT"
#       },
#       "end": {
#         "value": 42,
#         "modifier": "EXACT"
#       }
#     },
#     "description": "",
#     "evidences": [
#       {
#         "evidenceCode": "ECO:0007829",
#         "source": "PDB",
#         "id": "3URF"
#       }
#     ]
#   },
#   {
#     "type": "Beta strand",
#     "location": {
#       "start": {
#         "value": 48,
#         "modifier": "EXACT"
#       },
#       "end": {
#         "value": 52,
#         "modifier": "EXACT"
#       }
#     },
#     "description": "",
#     "evidences": [
#       {
#         "evidenceCode": "ECO:0007829",
#         "source": "PDB",
#         "id": "3URF"
#       }
#     ]
#   },
#   {
#     "type": "Beta strand",
#     "location": {
#       "start": {
#         "value": 56,
#         "modifier": "EXACT"
#       },
#       "end": {
#         "value": 58,
#         "modifier": "EXACT"
#       }
#     },
#     "description": "",
#     "evidences": [
#       {
#         "evidenceCode": "ECO:0007829",
#         "source": "PDB",
#         "id": "3URF"
#       }
#     ]
#   },
#   {
#     "type": "Beta strand",
#     "location": {
#       "start": {
#         "value": 61,
#         "modifier": "EXACT"
#       },
#       "end": {
#         "value": 64,
#         "modifier": "EXACT"
#       }
#     },
#     "description": "",
#     "evidences": [
#       {
#         "evidenceCode": "ECO:0007829",
#         "source": "PDB",
#         "id": "3URF"
#       }
#     ]
#   },
#   {
#     "type": "Beta strand",
#     "location": {
#       "start": {
#         "value": 91,
#         "modifier": "EXACT"
#       },
#       "end": {
#         "value": 95,
#         "modifier": "EXACT"
#       }
#     },
#     "description": "",
#     "evidences": [
#       {
#         "evidenceCode": "ECO:0007829",
#         "source": "PDB",
#         "id": "3URF"
#       }
#     ]
#   },
#   {
#     "type": "Beta strand",
#     "location": {
#       "start": {
#         "value": 99,
#         "modifier": "EXACT"
#       },
#       "end": {
#         "value": 101,
#         "modifier": "EXACT"
#       }
#     },
#     "description": "",
#     "evidences": [
#       {
#         "evidenceCode": "ECO:0007829",
#         "source": "PDB",
#         "id": "3URF"
#       }
#     ]
#   },
#   {
#     "type": "Beta strand",
#     "location": {
#       "start": {
#         "value": 104,
#         "modifier": "EXACT"
#       },
#       "end": {
#         "value": 107,
#         "modifier": "EXACT"
#       }
#     },
#     "description": "",
#     "evidences": [
#       {
#         "evidenceCode": "ECO:0007829",
#         "source": "PDB",
#         "id": "3URF"
#       }
#     ]
#   },
#   {
#     "type": "Beta strand",
#     "location": {
#       "start": {
#         "value": 111,
#         "modifier": "EXACT"
#       },
#       "end": {
#         "value": 114,
#         "modifier": "EXACT"
#       }
#     },
#     "description": "",
#     "evidences": [
#       {
#         "evidenceCode": "ECO:0007829",
#         "source": "PDB",
#         "id": "3URF"
#       }
#     ]
#   },
#   {
#     "type": "Beta strand",
#     "location": {
#       "start": {
#         "value": 117,
#         "modifier": "EXACT"
#       },
#       "end": {
#         "value": 120,
#         "modifier": "EXACT"
#       }
#     },
#     "description": "",
#     "evidences": [
#       {
#         "evidenceCode": "ECO:0007829",
#         "source": "PDB",
#         "id": "3URF"
#       }
#     ]
#   },
#   {
#     "type": "Beta strand",
#     "location": {
#       "start": {
#         "value": 128,
#         "modifier": "EXACT"
#       },
#       "end": {
#         "value": 132,
#         "modifier": "EXACT"
#       }
#     },
#     "description": "",
#     "evidences": [
#       {
#         "evidenceCode": "ECO:0007829",
#         "source": "PDB",
#         "id": "3URF"
#       }
#     ]
#   },
#   {
#     "type": "Beta strand",
#     "location": {
#       "start": {
#         "value": 136,
#         "modifier": "EXACT"
#       },
#       "end": {
#         "value": 138,
#         "modifier": "EXACT"
#       }
#     },
#     "description": "",
#     "evidences": [
#       {
#         "evidenceCode": "ECO:0007829",
#         "source": "PDB",
#         "id": "3URF"
#       }
#     ]
#   },
#   {
#     "type": "Beta strand",
#     "location": {
#       "start": {
#         "value": 141,
#         "modifier": "EXACT"
#       },
#       "end": {
#         "value": 144,
#         "modifier": "EXACT"
#       }
#     },
#     "description": "",
#     "evidences": [
#       {
#         "evidenceCode": "ECO:0007829",
#         "source": "PDB",
#         "id": "3URF"
#       }
#     ]
#   },
#   {
#     "type": "Beta strand",
#     "location": {
#       "start": {
#         "value": 155,
#         "modifier": "EXACT"
#       },
#       "end": {
#         "value": 157,
#         "modifier": "EXACT"
#       }
#     },
#     "description": "",
#     "evidences": [
#       {
#         "evidenceCode": "ECO:0007829",
#         "source": "PDB",
#         "id": "3URF"
#       }
#     ]
#   },
#   {
#     "type": "Beta strand",
#     "location": {
#       "start": {
#         "value": 167,
#         "modifier": "EXACT"
#       },
#       "end": {
#         "value": 171,
#         "modifier": "EXACT"
#       }
#     },
#     "description": "",
#     "evidences": [
#       {
#         "evidenceCode": "ECO:0007829",
#         "source": "PDB",
#         "id": "3URF"
#       }
#     ]
#   }
# ]

# %%
def get_kingdom(entry):
  """
  The function get_kingdom search the kingdom of the entry following the JSON structure.
  """

  if "Metazoa" in entry["organism"]["lineage"]:
    k = "Metazoa"
  elif "Viridiplantae" in entry["organism"]["lineage"]:
    k = "Viridiplantae"
  elif "Fungi" in entry["organism"]["lineage"]:
    k = "Fungi"
  else:
    k = "Other"
  return k

def filter_entry_positive(entry):
  """
  The function filter_entry_positive filter the entries following the criteria:
  - presence of the SP-cleavage site (looking for the presence of the end position)
  - length of the SP (SP>14)
  """

  try:
      e_pos = int(entry["features"][0]["location"]["end"]["value"])

      # If description != "" there is no cleavage site
      if entry["features"][0]["description"] != "":
          return False

      # keep only entries with SP length>14 aa
      if e_pos <= 13:
          return False

      return True

  except (KeyError, IndexError, ValueError):
      return False


def filter_entry_negative(entry):
    return True


def json_to_tsv_positive(entry):
  """
  The function json_to_tsv_positive retrieves the information to save in .tsv  file.
  """
  return (entry["primaryAccession"],
          entry["organism"]["scientificName"],
          get_kingdom(entry),
          entry["sequence"]["length"],
          entry["features"][0]["location"]["end"]["value"])

def json_to_tsv_negative(entry):
  """
  The function json_to_tsv_negative look for the presence of transmembrane helices in the first 90 aa of the entries,
  in order to discriminate SP from transmembrane helices and reduce FPR.
  """

  k = get_kingdom(entry)

  tm_evidence = False
  for f in entry["features"]:
      if f["type"]=="Transmembrane":
        if re.search("Helical",f["description"]):
          if f["location"]["start"]["value"]<=90:
            tm_evidence = True
            break

  return (entry["primaryAccession"],
          entry["organism"]["scientificName"],
          get_kingdom(entry),
          entry["sequence"]["length"],
          tm_evidence)


def get_dataset(search_url, filter_function, json_to_tsv_function, columns, tsv_file, fasta_file):
  """
  The function get_dataset process all batches and prints the total number of entries and the filtered number of entries.
  """
  n_total, n_filtered = 0, 0

  with open(tsv_file, 'w') as tsv, open(fasta_file, 'w') as fasta:
    print(*columns, sep="\t", file=tsv)

    for batch, total in get_batch(search_url):
        data = json.loads(batch.text)["results"]

        # Loop through each individual entry in the 'results' list of the JSON data
        for entry in data:
          n_total += 1

          # Check if the entry meets the criteria defined by filter_function
          if filter_function(entry):
            n_filtered += 1
            fields = json_to_tsv_function(entry)
            print(*fields, sep="\t", file=tsv)
            print(">", entry["primaryAccession"], sep="", file=fasta)
            print(entry["sequence"]["value"], file=fasta)

  print(f"Total: {n_total}\nFiltered: {n_filtered}")

# %%
if __name__ == "__main__":
  print('Positive entries:')
  get_dataset(url_positive, filter_entry_positive, json_to_tsv_positive, col_positive, "positive.tsv", "positive.fasta")
  print('\nNegative entries:')
  get_dataset(url_negative, filter_entry_negative, json_to_tsv_negative, col_negative, "negative.tsv", "negative.fasta")
# Out:
# Positive entries:
# https://rest.uniprot.org/uniprotkb/search?format=json&query=%28%28fragment%3Afalse%29%20AND%20%28taxonomy_id%3A2759%29%20AND%20%28length%3A%5B40%20TO%20%2A%5D%29%20AND%20%28reviewed%3Atrue%29%20AND%20%28existence%3A1%29%20AND%20%28ft_signal_exp%3A%2A%29%29&cursor=c9bacmxsqhkqgdxgnaquhsybhmvuelm5fxu0j&size=500
# https://rest.uniprot.org/uniprotkb/search?format=json&query=%28%28fragment%3Afalse%29%20AND%20%28taxonomy_id%3A2759%29%20AND%20%28length%3A%5B40%20TO%20%2A%5D%29%20AND%20%28reviewed%3Atrue%29%20AND%20%28existence%3A1%29%20AND%20%28ft_signal_exp%3A%2A%29%29&cursor=28m7xk8oeejl5mhhil7voukl953i9phd2w397hu&size=500
# https://rest.uniprot.org/uniprotkb/search?format=json&query=%28%28fragment%3Afalse%29%20AND%20%28taxonomy_id%3A2759%29%20AND%20%28length%3A%5B40%20TO%20%2A%5D%29%20AND%20%28reviewed%3Atrue%29%20AND%20%28existence%3A1%29%20AND%20%28ft_signal_exp%3A%2A%29%29&cursor=28ndf240hnvwz75t65klyjzcujbd3y9nn3i5gky&size=500
# https://rest.uniprot.org/uniprotkb/search?format=json&query=%28%28fragment%3Afalse%29%20AND%20%28taxonomy_id%3A2759%29%20AND%20%28length%3A%5B40%20TO%20%2A%5D%29%20AND%20%28reviewed%3Atrue%29%20AND%20%28existence%3A1%29%20AND%20%28ft_signal_exp%3A%2A%29%29&cursor=2a980kt2mw2stfh9pzwmkrx6jej9kv0lhaz4z01&size=500
# https://rest.uniprot.org/uniprotkb/search?format=json&query=%28%28fragment%3Afalse%29%20AND%20%28taxonomy_id%3A2759%29%20AND%20%28length%3A%5B40%20TO%20%2A%5D%29%20AND%20%28reviewed%3Atrue%29%20AND%20%28existence%3A1%29%20AND%20%28ft_signal_exp%3A%2A%29%29&cursor=2aadi2oeq5f4n05lcw735m1ik2o3bi1ins3zvht&size=500
# None
# Total: 2949
# Filtered: 2932
#
# Negative entries:
# https://rest.uniprot.org/uniprotkb/search?format=json&query=%28%28reviewed%3Atrue%29%20AND%20%28fragment%3Afalse%29%20AND%20%28taxonomy_id%3A2759%29%20AND%20%28length%3A%5B40%20TO%20%2A%5D%29%20AND%20%28existence%3A1%29%20NOT%20%28ft_signal%3A%2A%29%20OR%20%28cc_scl_term_exp%3ASL-0191%29%20OR%20%28cc_scl_term_exp%3ASL-0204%29%20OR%20%28cc_scl_term_exp%3ASL-0039%29%20OR%20%28cc_scl_term_exp%3ASL-0091%29%20OR%20%28cc_scl_term_exp%3ASL-0209%29%20OR%20%28cc_scl_term_exp%3ASL-0173%29%29&cursor=c9bacmxsqhkqgdxflkgr8ocjvob9drkxr36lx&size=500
# https://rest.uniprot.org/uniprotkb/search?format=json&query=%28%28reviewed%3Atrue%29%20AND%20%28fragment%3Afalse%29%20AND%20%28taxonomy_id%3A2759%29%20AND%20%28length%3A%5B40%20TO%20%2A%5D%29%20AND%20%28existence%3A1%29%20NOT%20%28ft_signal%3A%2A%29%20OR%20%28cc_scl_term_exp%3ASL-0191%29%20OR%20%28cc_scl_term_exp%3ASL-0204%29%20OR%20%28cc_scl_term_exp%3ASL-0039%29%20OR%20%28cc_scl_term_exp%3ASL-0091%29%20OR%20%28cc_scl_term_exp%3ASL-0209%29%20OR%20%28cc_scl_term_exp%3ASL-0173%29%29&cursor=28m7xk8oeejl5mhhj8zls7kvay5u9y7xsakk6ew&size=500
# https://rest.uniprot.org/uniprotkb/search?format=json&query=%28%28reviewed%3Atrue%29%20AND%20%28fragment%3Afalse%29%20AND%20%28taxonomy_id%3A2759%29%20AND%20%28length%3A%5B40%20TO%20%2A%5D%29%20AND%20%28existence%3A1%29%20NOT%20%28ft_signal%3A%2A%29%20OR%20%28cc_scl_term_exp%3ASL-0191%29%20OR%20%28cc_scl_term_exp%3ASL-0204%29%20OR%20%28cc_scl_term_exp%3ASL-0039%29%20OR%20%28cc_scl_term_exp%3ASL-0091%29%20OR%20%28cc_scl_term_exp%3ASL-0209%29%20OR%20%28cc_scl_term_exp%3ASL-0173%29%29&cursor=28ndf240hnvwz75t716vknf0h93aqp5dmzgjw38&size=500
# https://rest.uniprot.org/uniprotkb/search?format=json&query=%28%28reviewed%3Atrue%29%20AND%20%28fragment%3Afalse%29%20AND%20%28taxonomy_id%3A2759%29%20AND%20%28length%3A%5B40%20TO%20%2A%5D%29%20AND%20%28existence%3A1%29%20NOT%20%28ft_signal%3A%2A%29%20OR%20%28cc_scl_term_exp%3ASL-0191%29%20OR%20%28cc_scl_term_exp%3ASL-0204%29%20OR%20%28cc_scl_term_exp%3ASL-0039%29%20OR%20%28cc_scl_term_exp%3ASL-0091%29%20OR%20%28cc_scl_term_exp%3ASL-0209%29%20OR%20%28cc_scl_term_exp%3ASL-0173%29%29&cursor=2a980kt2mw2stfh9rirugy0c7cpzid5itzu9gfs&size=500
# https://rest.uniprot.org/uniprotkb/search?format=json&query=%28%28reviewed%3Atrue%29%20AND%20%28fragment%3Afalse%29%20AND%20%28taxonomy_id%3A2759%29%20AND%20%28length%3A%5B40%20TO%20%2A%5D%29%20AND%20%28existence%3A1%29%20NOT%20%28ft_signal%3A%2A%29%20OR%20%28cc_scl_term_exp%3ASL-0191%29%20OR%20%28cc_scl_term_exp%3ASL-0204%29%20OR%20%28cc_scl_term_exp%3ASL-0039%29%20OR%20%28cc_scl_term_exp%3ASL-0091%29%20OR%20%28cc_scl_term_exp%3ASL-0209%29%20OR%20%28cc_scl_term_exp%3ASL-0173%29%29&cursor=2aadi2oeq5f4n05lfaywzixmzyjsnpn2gai78z6&size=500
# https://rest.uniprot.org/uniprotkb/search?format=json&query=%28%28reviewed%3Atrue%29%20AND%20%28fragment%3Afalse%29%20AND%20%28taxonomy_id%3A2759%29%20AND%20%28length%3A%5B40%20TO%20%2A%5D%29%20AND%20%28existence%3A1%29%20NOT%20%28ft_signal%3A%2A%29%20OR%20%28cc_scl_term_exp%3ASL-0191%29%20OR%20%28cc_scl_term_exp%3ASL-0204%29%20OR%20%28cc_scl_term_exp%3ASL-0039%29%20OR%20%28cc_scl_term_exp%3ASL-0091%29%20OR%20%28cc_scl_term_exp%3ASL-0209%29%20OR%20%28cc_scl_term_exp%3ASL-0173%29%29&cursor=2bw83ldgvdm0h8h1zs9v2q48p2fm1cwneb900tx&size=500
# https://rest.uniprot.org/uniprotkb/search?format=json&query=%28%28reviewed%3Atrue%29%20AND%20%28fragment%3Afalse%29%20AND%20%28taxonomy_id%3A2759%29%20AND%20%28length%3A%5B40%20TO%20%2A%5D%29%20AND%20%28existence%3A1%29%20NOT%20%28ft_signal%3A%2A%29%20OR%20%28cc_scl_term_exp%3ASL-0191%29%20OR%20%28cc_scl_term_exp%3ASL-0204%29%20OR%20%28cc_scl_term_exp%3ASL-0039%29%20OR%20%28cc_scl_term_exp%3ASL-0091%29%20OR%20%28cc_scl_term_exp%3ASL-0209%29%20OR%20%28cc_scl_term_exp%3ASL-0173%29%29&cursor=2bxdl38symycat5dnkgtd7ckj3y2dztsrx4urzm&size=500
# https://rest.uniprot.org/uniprotkb/search?format=json&query=%28%28reviewed%3Atrue%29%20AND%20%28fragment%3Afalse%29%20AND%20%28taxonomy_id%3A2759%29%20AND%20%28length%3A%5B40%20TO%20%2A%5D%29%20AND%20%28existence%3A1%29%20NOT%20%28ft_signal%3A%2A%29%20OR%20%28cc_scl_term_exp%3ASL-0191%29%20OR%20%28cc_scl_term_exp%3ASL-0204%29%20OR%20%28cc_scl_term_exp%3ASL-0039%29%20OR%20%28cc_scl_term_exp%3ASL-0091%29%20OR%20%28cc_scl_term_exp%3ASL-0209%29%20OR%20%28cc_scl_term_exp%3ASL-0173%29%29&cursor=2dj86lxv3v5851gu81yviutfjq43i3h17f5mcdu&size=500
# https://rest.uniprot.org/uniprotkb/search?format=json&query=%28%28reviewed%3Atrue%29%20AND%20%28fragment%3Afalse%29%20AND%20%28taxonomy_id%3A2759%29%20AND%20%28length%3A%5B40%20TO%20%2A%5D%29%20AND%20%28existence%3A1%29%20NOT%20%28ft_signal%3A%2A%29%20OR%20%28cc_scl_term_exp%3ASL-0191%29%20OR%20%28cc_scl_term_exp%3ASL-0204%29%20OR%20%28cc_scl_term_exp%3ASL-0039%29%20OR%20%28cc_scl_term_exp%3ASL-0091%29%20OR%20%28cc_scl_term_exp%3ASL-0209%29%20OR%20%28cc_scl_term_exp%3ASL-0173%29%29&cursor=2dkdo3t774hjym55vu5vqan8s9d6kfghrs57eb8&size=500
# https://rest.uniprot.org/uniprotkb/search?format=json&query=%28%28reviewed%3Atrue%29%20AND%20%28fragment%3Afalse%29%20AND%20%28taxonomy_id%3A2759%29%20AND%20%28length%3A%5B40%20TO%20%2A%5D%29%20AND%20%28existence%3A1%29%20NOT%20%28ft_signal%3A%2A%29%20OR%20%28cc_scl_term_exp%3ASL-0191%29%20OR%20%28cc_scl_term_exp%3ASL-0204%29%20OR%20%28cc_scl_term_exp%3ASL-0039%29%20OR%20%28cc_scl_term_exp%3ASL-0091%29%20OR%20%28cc_scl_term_exp%3ASL-0209%29%20OR%20%28cc_scl_term_exp%3ASL-0173%29%29&cursor=2f689mi9ccofsugmgbny9qzxcrbluc57lnfeb93&size=500
# https://rest.uniprot.org/uniprotkb/search?format=json&query=%28%28reviewed%3Atrue%29%20AND%20%28fragment%3Afalse%29%20AND%20%28taxonomy_id%3A2759%29%20AND%20%28length%3A%5B40%20TO%20%2A%5D%29%20AND%20%28existence%3A1%29%20NOT%20%28ft_signal%3A%2A%29%20OR%20%28cc_scl_term_exp%3ASL-0191%29%20OR%20%28cc_scl_term_exp%3ASL-0204%29%20OR%20%28cc_scl_term_exp%3ASL-0039%29%20OR%20%28cc_scl_term_exp%3ASL-0091%29%20OR%20%28cc_scl_term_exp%3ASL-0209%29%20OR%20%28cc_scl_term_exp%3ASL-0173%29%29&cursor=2f7dr4dlfm0rmf4y43s5jylllrapt4m2zj8pp9t&size=500
# https://rest.uniprot.org/uniprotkb/search?format=json&query=%28%28reviewed%3Atrue%29%20AND%20%28fragment%3Afalse%29%20AND%20%28taxonomy_id%3A2759%29%20AND%20%28length%3A%5B40%20TO%20%2A%5D%29%20AND%20%28existence%3A1%29%20NOT%20%28ft_signal%3A%2A%29%20OR%20%28cc_scl_term_exp%3ASL-0191%29%20OR%20%28cc_scl_term_exp%3ASL-0204%29%20OR%20%28cc_scl_term_exp%3ASL-0039%29%20OR%20%28cc_scl_term_exp%3ASL-0091%29%20OR%20%28cc_scl_term_exp%3ASL-0209%29%20OR%20%28cc_scl_term_exp%3ASL-0173%29%29&cursor=2gt8cn2nku7ngngeol5qzelynae0lew4t9343sk&size=500
# https://rest.uniprot.org/uniprotkb/search?format=json&query=%28%28reviewed%3Atrue%29%20AND%20%28fragment%3Afalse%29%20AND%20%28taxonomy_id%3A2759%29%20AND%20%28length%3A%5B40%20TO%20%2A%5D%29%20AND%20%28existence%3A1%29%20NOT%20%28ft_signal%3A%2A%29%20OR%20%28cc_scl_term_exp%3ASL-0191%29%20OR%20%28cc_scl_term_exp%3ASL-0204%29%20OR%20%28cc_scl_term_exp%3ASL-0039%29%20OR%20%28cc_scl_term_exp%3ASL-0091%29%20OR%20%28cc_scl_term_exp%3ASL-0209%29%20OR%20%28cc_scl_term_exp%3ASL-0173%29%29&cursor=2gudu4xzo3jza84qc4gcvekt5e35oldoa6yvp6c&size=500
# https://rest.uniprot.org/uniprotkb/search?format=json&query=%28%28reviewed%3Atrue%29%20AND%20%28fragment%3Afalse%29%20AND%20%28taxonomy_id%3A2759%29%20AND%20%28length%3A%5B40%20TO%20%2A%5D%29%20AND%20%28existence%3A1%29%20NOT%20%28ft_signal%3A%2A%29%20OR%20%28cc_scl_term_exp%3ASL-0191%29%20OR%20%28cc_scl_term_exp%3ASL-0204%29%20OR%20%28cc_scl_term_exp%3ASL-0039%29%20OR%20%28cc_scl_term_exp%3ASL-0091%29%20OR%20%28cc_scl_term_exp%3ASL-0209%29%20OR%20%28cc_scl_term_exp%3ASL-0173%29%29&cursor=2ig8fnn1tbqv4gg6wl7cs1evjt6bu8zw271wgms&size=500
# https://rest.uniprot.org/uniprotkb/search?format=json&query=%28%28reviewed%3Atrue%29%20AND%20%28fragment%3Afalse%29%20AND%20%28taxonomy_id%3A2759%29%20AND%20%28length%3A%5B40%20TO%20%2A%5D%29%20AND%20%28existence%3A1%29%20NOT%20%28ft_signal%3A%2A%29%20OR%20%28cc_scl_term_exp%3ASL-0191%29%20OR%20%28cc_scl_term_exp%3ASL-0204%29%20OR%20%28cc_scl_term_exp%3ASL-0039%29%20OR%20%28cc_scl_term_exp%3ASL-0091%29%20OR%20%28cc_scl_term_exp%3ASL-0209%29%20OR%20%28cc_scl_term_exp%3ASL-0173%29%29&cursor=2ihdx5idwl36y14ikcwbgk2l9w5dzlxuk3sl3jm&size=500
# https://rest.uniprot.org/uniprotkb/search?format=json&query=%28%28reviewed%3Atrue%29%20AND%20%28fragment%3Afalse%29%20AND%20%28taxonomy_id%3A2759%29%20AND%20%28length%3A%5B40%20TO%20%2A%5D%29%20AND%20%28existence%3A1%29%20NOT%20%28ft_signal%3A%2A%29%20OR%20%28cc_scl_term_exp%3ASL-0191%29%20OR%20%28cc_scl_term_exp%3ASL-0204%29%20OR%20%28cc_scl_term_exp%3ASL-0039%29%20OR%20%28cc_scl_term_exp%3ASL-0091%29%20OR%20%28cc_scl_term_exp%3ASL-0209%29%20OR%20%28cc_scl_term_exp%3ASL-0173%29%29&cursor=2k38io7g1ta2s9fz4uiyjxx46eamfxrw2lp7391&size=500
# https://rest.uniprot.org/uniprotkb/search?format=json&query=%28%28reviewed%3Atrue%29%20AND%20%28fragment%3Afalse%29%20AND%20%28taxonomy_id%3A2759%29%20AND%20%28length%3A%5B40%20TO%20%2A%5D%29%20AND%20%28existence%3A1%29%20NOT%20%28ft_signal%3A%2A%29%20OR%20%28cc_scl_term_exp%3ASL-0191%29%20OR%20%28cc_scl_term_exp%3ASL-0204%29%20OR%20%28cc_scl_term_exp%3ASL-0039%29%20OR%20%28cc_scl_term_exp%3ASL-0091%29%20OR%20%28cc_scl_term_exp%3ASL-0209%29%20OR%20%28cc_scl_term_exp%3ASL-0173%29%29&cursor=2k4e062s52melu4asmt2c06v1lbpp95d3q8ehbm&size=500
# https://rest.uniprot.org/uniprotkb/search?format=json&query=%28%28reviewed%3Atrue%29%20AND%20%28fragment%3Afalse%29%20AND%20%28taxonomy_id%3A2759%29%20AND%20%28length%3A%5B40%20TO%20%2A%5D%29%20AND%20%28existence%3A1%29%20NOT%20%28ft_signal%3A%2A%29%20OR%20%28cc_scl_term_exp%3ASL-0191%29%20OR%20%28cc_scl_term_exp%3ASL-0204%29%20OR%20%28cc_scl_term_exp%3ASL-0039%29%20OR%20%28cc_scl_term_exp%3ASL-0091%29%20OR%20%28cc_scl_term_exp%3ASL-0209%29%20OR%20%28cc_scl_term_exp%3ASL-0173%29%29&cursor=2lq8loruaatag2frd4fr3tm4g76fcz8s4u4n2bc&size=500
# https://rest.uniprot.org/uniprotkb/search?format=json&query=%28%28reviewed%3Atrue%29%20AND%20%28fragment%3Afalse%29%20AND%20%28taxonomy_id%3A2759%29%20AND%20%28length%3A%5B40%20TO%20%2A%5D%29%20AND%20%28existence%3A1%29%20NOT%20%28ft_signal%3A%2A%29%20OR%20%28cc_scl_term_exp%3ASL-0191%29%20OR%20%28cc_scl_term_exp%3ASL-0204%29%20OR%20%28cc_scl_term_exp%3ASL-0039%29%20OR%20%28cc_scl_term_exp%3ASL-0091%29%20OR%20%28cc_scl_term_exp%3ASL-0209%29%20OR%20%28cc_scl_term_exp%3ASL-0173%29%29&cursor=2lre36n6dk5m9n430wpj5wadne7lrycupaqsu47&size=500
# https://rest.uniprot.org/uniprotkb/search?format=json&query=%28%28reviewed%3Atrue%29%20AND%20%28fragment%3Afalse%29%20AND%20%28taxonomy_id%3A2759%29%20AND%20%28length%3A%5B40%20TO%20%2A%5D%29%20AND%20%28existence%3A1%29%20NOT%20%28ft_signal%3A%2A%29%20OR%20%28cc_scl_term_exp%3ASL-0191%29%20OR%20%28cc_scl_term_exp%3ASL-0204%29%20OR%20%28cc_scl_term_exp%3ASL-0039%29%20OR%20%28cc_scl_term_exp%3ASL-0091%29%20OR%20%28cc_scl_term_exp%3ASL-0209%29%20OR%20%28cc_scl_term_exp%3ASL-0173%29%29&cursor=fxa0enycnfflwcma96nz41t3ybf1774ijgt210z9&size=500
# https://rest.uniprot.org/uniprotkb/search?format=json&query=%28%28reviewed%3Atrue%29%20AND%20%28fragment%3Afalse%29%20AND%20%28taxonomy_id%3A2759%29%20AND%20%28length%3A%5B40%20TO%20%2A%5D%29%20AND%20%28existence%3A1%29%20NOT%20%28ft_signal%3A%2A%29%20OR%20%28cc_scl_term_exp%3ASL-0191%29%20OR%20%28cc_scl_term_exp%3ASL-0204%29%20OR%20%28cc_scl_term_exp%3ASL-0039%29%20OR%20%28cc_scl_term_exp%3ASL-0091%29%20OR%20%28cc_scl_term_exp%3ASL-0209%29%20OR%20%28cc_scl_term_exp%3ASL-0173%29%29&cursor=fxa1k5g7zioy866ykug9482lllgi6129q0m48mr8&size=500
# https://rest.uniprot.org/uniprotkb/search?format=json&query=%28%28reviewed%3Atrue%29%20AND%20%28fragment%3Afalse%29%20AND%20%28taxonomy_id%3A2759%29%20AND%20%28length%3A%5B40%20TO%20%2A%5D%29%20AND%20%28existence%3A1%29%20NOT%20%28ft_signal%3A%2A%29%20OR%20%28cc_scl_term_exp%3ASL-0191%29%20OR%20%28cc_scl_term_exp%3ASL-0204%29%20OR%20%28cc_scl_term_exp%3ASL-0039%29%20OR%20%28cc_scl_term_exp%3ASL-0091%29%20OR%20%28cc_scl_term_exp%3ASL-0209%29%20OR%20%28cc_scl_term_exp%3ASL-0173%29%29&cursor=fxbneqyx1nx540fa1exvsziz161lyz5s0iwaojnc&size=500
# https://rest.uniprot.org/uniprotkb/search?format=json&query=%28%28reviewed%3Atrue%29%20AND%20%28fragment%3Afalse%29%20AND%20%28taxonomy_id%3A2759%29%20AND%20%28length%3A%5B40%20TO%20%2A%5D%29%20AND%20%28existence%3A1%29%20NOT%20%28ft_signal%3A%2A%29%20OR%20%28cc_scl_term_exp%3ASL-0191%29%20OR%20%28cc_scl_term_exp%3ASL-0204%29%20OR%20%28cc_scl_term_exp%3ASL-0039%29%20OR%20%28cc_scl_term_exp%3ASL-0091%29%20OR%20%28cc_scl_term_exp%3ASL-0209%29%20OR%20%28cc_scl_term_exp%3ASL-0173%29%29&cursor=fxbok8gsdr6hftzyd2eg3qad3n51adh8h3rc8e2c&size=500
# https://rest.uniprot.org/uniprotkb/search?format=json&query=%28%28reviewed%3Atrue%29%20AND%20%28fragment%3Afalse%29%20AND%20%28taxonomy_id%3A2759%29%20AND%20%28length%3A%5B40%20TO%20%2A%5D%29%20AND%20%28existence%3A1%29%20NOT%20%28ft_signal%3A%2A%29%20OR%20%28cc_scl_term_exp%3ASL-0191%29%20OR%20%28cc_scl_term_exp%3ASL-0204%29%20OR%20%28cc_scl_term_exp%3ASL-0039%29%20OR%20%28cc_scl_term_exp%3ASL-0091%29%20OR%20%28cc_scl_term_exp%3ASL-0209%29%20OR%20%28cc_scl_term_exp%3ASL-0173%29%29&cursor=fxdaetzhfweobo89tmwnymsnyps2cvv7wt275gs1&size=500
# https://rest.uniprot.org/uniprotkb/search?format=json&query=%28%28reviewed%3Atrue%29%20AND%20%28fragment%3Afalse%29%20AND%20%28taxonomy_id%3A2759%29%20AND%20%28length%3A%5B40%20TO%20%2A%5D%29%20AND%20%28existence%3A1%29%20NOT%20%28ft_signal%3A%2A%29%20OR%20%28cc_scl_term_exp%3ASL-0191%29%20OR%20%28cc_scl_term_exp%3ASL-0204%29%20OR%20%28cc_scl_term_exp%3ASL-0039%29%20OR%20%28cc_scl_term_exp%3ASL-0091%29%20OR%20%28cc_scl_term_exp%3ASL-0209%29%20OR%20%28cc_scl_term_exp%3ASL-0173%29%29&cursor=fxdbkbhcrzo0nhsy5aot7322u1lstvk0t21jwraq&size=500
# https://rest.uniprot.org/uniprotkb/search?format=json&query=%28%28reviewed%3Atrue%29%20AND%20%28fragment%3Afalse%29%20AND%20%28taxonomy_id%3A2759%29%20AND%20%28length%3A%5B40%20TO%20%2A%5D%29%20AND%20%28existence%3A1%29%20NOT%20%28ft_signal%3A%2A%29%20OR%20%28cc_scl_term_exp%3ASL-0191%29%20OR%20%28cc_scl_term_exp%3ASL-0204%29%20OR%20%28cc_scl_term_exp%3ASL-0039%29%20OR%20%28cc_scl_term_exp%3ASL-0091%29%20OR%20%28cc_scl_term_exp%3ASL-0209%29%20OR%20%28cc_scl_term_exp%3ASL-0173%29%29&cursor=fxexex01u4w7jc19lv6el38b6v9vy43b9jipucs1&size=500
# https://rest.uniprot.org/uniprotkb/search?format=json&query=%28%28reviewed%3Atrue%29%20AND%20%28fragment%3Afalse%29%20AND%20%28taxonomy_id%3A2759%29%20AND%20%28length%3A%5B40%20TO%20%2A%5D%29%20AND%20%28existence%3A1%29%20NOT%20%28ft_signal%3A%2A%29%20OR%20%28cc_scl_term_exp%3ASL-0191%29%20OR%20%28cc_scl_term_exp%3ASL-0204%29%20OR%20%28cc_scl_term_exp%3ASL-0039%29%20OR%20%28cc_scl_term_exp%3ASL-0091%29%20OR%20%28cc_scl_term_exp%3ASL-0209%29%20OR%20%28cc_scl_term_exp%3ASL-0173%29%29&cursor=fxeykehx685jv5lxxiyk6c7uvav1pfamefzqjyih&size=500
# https://rest.uniprot.org/uniprotkb/search?format=json&query=%28%28reviewed%3Atrue%29%20AND%20%28fragment%3Afalse%29%20AND%20%28taxonomy_id%3A2759%29%20AND%20%28length%3A%5B40%20TO%20%2A%5D%29%20AND%20%28existence%3A1%29%20NOT%20%28ft_signal%3A%2A%29%20OR%20%28cc_scl_term_exp%3ASL-0191%29%20OR%20%28cc_scl_term_exp%3ASL-0204%29%20OR%20%28cc_scl_term_exp%3ASL-0039%29%20OR%20%28cc_scl_term_exp%3ASL-0091%29%20OR%20%28cc_scl_term_exp%3ASL-0209%29%20OR%20%28cc_scl_term_exp%3ASL-0173%29%29&cursor=fxgkf00m8ddqqzu9e3j6tlonkjum5e7ymwh3cp4i&size=500
# https://rest.uniprot.org/uniprotkb/search?format=json&query=%28%28reviewed%3Atrue%29%20AND%20%28fragment%3Afalse%29%20AND%20%28taxonomy_id%3A2759%29%20AND%20%28length%3A%5B40%20TO%20%2A%5D%29%20AND%20%28existence%3A1%29%20NOT%20%28ft_signal%3A%2A%29%20OR%20%28cc_scl_term_exp%3ASL-0191%29%20OR%20%28cc_scl_term_exp%3ASL-0204%29%20OR%20%28cc_scl_term_exp%3ASL-0039%29%20OR%20%28cc_scl_term_exp%3ASL-0091%29%20OR%20%28cc_scl_term_exp%3ASL-0209%29%20OR%20%28cc_scl_term_exp%3ASL-0173%29%29&cursor=fxglkhihkgn32texprbaoos4hhw3p0c3z5p43y48&size=500
# https://rest.uniprot.org/uniprotkb/search?format=json&query=%28%28reviewed%3Atrue%29%20AND%20%28fragment%3Afalse%29%20AND%20%28taxonomy_id%3A2759%29%20AND%20%28length%3A%5B40%20TO%20%2A%5D%29%20AND%20%28existence%3A1%29%20NOT%20%28ft_signal%3A%2A%29%20OR%20%28cc_scl_term_exp%3ASL-0191%29%20OR%20%28cc_scl_term_exp%3ASL-0204%29%20OR%20%28cc_scl_term_exp%3ASL-0039%29%20OR%20%28cc_scl_term_exp%3ASL-0091%29%20OR%20%28cc_scl_term_exp%3ASL-0209%29%20OR%20%28cc_scl_term_exp%3ASL-0173%29%29&cursor=fxi7f316mlv9ynn96bquzq9c827lb51kn36w4rox&size=500
# https://rest.uniprot.org/uniprotkb/search?format=json&query=%28%28reviewed%3Atrue%29%20AND%20%28fragment%3Afalse%29%20AND%20%28taxonomy_id%3A2759%29%20AND%20%28length%3A%5B40%20TO%20%2A%5D%29%20AND%20%28existence%3A1%29%20NOT%20%28ft_signal%3A%2A%29%20OR%20%28cc_scl_term_exp%3ASL-0191%29%20OR%20%28cc_scl_term_exp%3ASL-0204%29%20OR%20%28cc_scl_term_exp%3ASL-0039%29%20OR%20%28cc_scl_term_exp%3ASL-0091%29%20OR%20%28cc_scl_term_exp%3ASL-0209%29%20OR%20%28cc_scl_term_exp%3ASL-0173%29%29&cursor=fxi8kkj1yp4mah7xhz7r37tnv139yruu5bcoesu2&size=500
# https://rest.uniprot.org/uniprotkb/search?format=json&query=%28%28reviewed%3Atrue%29%20AND%20%28fragment%3Afalse%29%20AND%20%28taxonomy_id%3A2759%29%20AND%20%28length%3A%5B40%20TO%20%2A%5D%29%20AND%20%28existence%3A1%29%20NOT%20%28ft_signal%3A%2A%29%20OR%20%28cc_scl_term_exp%3ASL-0191%29%20OR%20%28cc_scl_term_exp%3ASL-0204%29%20OR%20%28cc_scl_term_exp%3ASL-0039%29%20OR%20%28cc_scl_term_exp%3ASL-0091%29%20OR%20%28cc_scl_term_exp%3ASL-0209%29%20OR%20%28cc_scl_term_exp%3ASL-0173%29%29&cursor=fxjuf61r0uct6bg8yjr13lrtf311ah624bwevc6v&size=500
# https://rest.uniprot.org/uniprotkb/search?format=json&query=%28%28reviewed%3Atrue%29%20AND%20%28fragment%3Afalse%29%20AND%20%28taxonomy_id%3A2759%29%20AND%20%28length%3A%5B40%20TO%20%2A%5D%29%20AND%20%28existence%3A1%29%20NOT%20%28ft_signal%3A%2A%29%20OR%20%28cc_scl_term_exp%3ASL-0191%29%20OR%20%28cc_scl_term_exp%3ASL-0204%29%20OR%20%28cc_scl_term_exp%3ASL-0039%29%20OR%20%28cc_scl_term_exp%3ASL-0091%29%20OR%20%28cc_scl_term_exp%3ASL-0209%29%20OR%20%28cc_scl_term_exp%3ASL-0173%29%29&cursor=fxjvknjmcxm5i50xa78lsuzy6nkbbpzfdo8wimbb&size=500
# https://rest.uniprot.org/uniprotkb/search?format=json&query=%28%28reviewed%3Atrue%29%20AND%20%28fragment%3Afalse%29%20AND%20%28taxonomy_id%3A2759%29%20AND%20%28length%3A%5B40%20TO%20%2A%5D%29%20AND%20%28existence%3A1%29%20NOT%20%28ft_signal%3A%2A%29%20OR%20%28cc_scl_term_exp%3ASL-0191%29%20OR%20%28cc_scl_term_exp%3ASL-0204%29%20OR%20%28cc_scl_term_exp%3ASL-0039%29%20OR%20%28cc_scl_term_exp%3ASL-0091%29%20OR%20%28cc_scl_term_exp%3ASL-0209%29%20OR%20%28cc_scl_term_exp%3ASL-0173%29%29&cursor=fxlhf92bf2ucdz98qrpy1wxc9ihm81iv4hisa453&size=500
# https://rest.uniprot.org/uniprotkb/search?format=json&query=%28%28reviewed%3Atrue%29%20AND%20%28fragment%3Afalse%29%20AND%20%28taxonomy_id%3A2759%29%20AND%20%28length%3A%5B40%20TO%20%2A%5D%29%20AND%20%28existence%3A1%29%20NOT%20%28ft_signal%3A%2A%29%20OR%20%28cc_scl_term_exp%3ASL-0191%29%20OR%20%28cc_scl_term_exp%3ASL-0204%29%20OR%20%28cc_scl_term_exp%3ASL-0039%29%20OR%20%28cc_scl_term_exp%3ASL-0091%29%20OR%20%28cc_scl_term_exp%3ASL-0209%29%20OR%20%28cc_scl_term_exp%3ASL-0173%29%29&cursor=fxlikqk6r63opstx2fhyr1h7w0i3drqevfkt99iw&size=500
# https://rest.uniprot.org/uniprotkb/search?format=json&query=%28%28reviewed%3Atrue%29%20AND%20%28fragment%3Afalse%29%20AND%20%28taxonomy_id%3A2759%29%20AND%20%28length%3A%5B40%20TO%20%2A%5D%29%20AND%20%28existence%3A1%29%20NOT%20%28ft_signal%3A%2A%29%20OR%20%28cc_scl_term_exp%3ASL-0191%29%20OR%20%28cc_scl_term_exp%3ASL-0204%29%20OR%20%28cc_scl_term_exp%3ASL-0039%29%20OR%20%28cc_scl_term_exp%3ASL-0091%29%20OR%20%28cc_scl_term_exp%3ASL-0209%29%20OR%20%28cc_scl_term_exp%3ASL-0173%29%29&cursor=fxn4fc2vtbbvln28izqkup3ctuuo60r3n2jmr8dx&size=500
# https://rest.uniprot.org/uniprotkb/search?format=json&query=%28%28reviewed%3Atrue%29%20AND%20%28fragment%3Afalse%29%20AND%20%28taxonomy_id%3A2759%29%20AND%20%28length%3A%5B40%20TO%20%2A%5D%29%20AND%20%28existence%3A1%29%20NOT%20%28ft_signal%3A%2A%29%20OR%20%28cc_scl_term_exp%3ASL-0191%29%20OR%20%28cc_scl_term_exp%3ASL-0204%29%20OR%20%28cc_scl_term_exp%3ASL-0039%29%20OR%20%28cc_scl_term_exp%3ASL-0091%29%20OR%20%28cc_scl_term_exp%3ASL-0209%29%20OR%20%28cc_scl_term_exp%3ASL-0173%29%29&cursor=fxn5ktkr5el7xgmwunhim7ppl5czxul7tztfxiyc&size=500
# https://rest.uniprot.org/uniprotkb/search?format=json&query=%28%28reviewed%3Atrue%29%20AND%20%28fragment%3Afalse%29%20AND%20%28taxonomy_id%3A2759%29%20AND%20%28length%3A%5B40%20TO%20%2A%5D%29%20AND%20%28existence%3A1%29%20NOT%20%28ft_signal%3A%2A%29%20OR%20%28cc_scl_term_exp%3ASL-0191%29%20OR%20%28cc_scl_term_exp%3ASL-0204%29%20OR%20%28cc_scl_term_exp%3ASL-0039%29%20OR%20%28cc_scl_term_exp%3ASL-0091%29%20OR%20%28cc_scl_term_exp%3ASL-0209%29%20OR%20%28cc_scl_term_exp%3ASL-0173%29%29&cursor=fxorff3g7jtetav8b7ezxqvzvpl26cf9zv52a6uq&size=500
# https://rest.uniprot.org/uniprotkb/search?format=json&query=%28%28reviewed%3Atrue%29%20AND%20%28fragment%3Afalse%29%20AND%20%28taxonomy_id%3A2759%29%20AND%20%28length%3A%5B40%20TO%20%2A%5D%29%20AND%20%28existence%3A1%29%20NOT%20%28ft_signal%3A%2A%29%20OR%20%28cc_scl_term_exp%3ASL-0191%29%20OR%20%28cc_scl_term_exp%3ASL-0204%29%20OR%20%28cc_scl_term_exp%3ASL-0039%29%20OR%20%28cc_scl_term_exp%3ASL-0091%29%20OR%20%28cc_scl_term_exp%3ASL-0209%29%20OR%20%28cc_scl_term_exp%3ASL-0173%29%29&cursor=fxoskwlbjn2r54fwmv5xiixhbqbqggs97s2apmpg&size=500
# https://rest.uniprot.org/uniprotkb/search?format=json&query=%28%28reviewed%3Atrue%29%20AND%20%28fragment%3Afalse%29%20AND%20%28taxonomy_id%3A2759%29%20AND%20%28length%3A%5B40%20TO%20%2A%5D%29%20AND%20%28existence%3A1%29%20NOT%20%28ft_signal%3A%2A%29%20OR%20%28cc_scl_term_exp%3ASL-0191%29%20OR%20%28cc_scl_term_exp%3ASL-0204%29%20OR%20%28cc_scl_term_exp%3ASL-0039%29%20OR%20%28cc_scl_term_exp%3ASL-0091%29%20OR%20%28cc_scl_term_exp%3ASL-0209%29%20OR%20%28cc_scl_term_exp%3ASL-0173%29%29&cursor=g8xl03zdvs48dmsqzzdwhpg4dpnv2oc4mtt4i4vn&size=500
# https://rest.uniprot.org/uniprotkb/search?format=json&query=%28%28reviewed%3Atrue%29%20AND%20%28fragment%3Afalse%29%20AND%20%28taxonomy_id%3A2759%29%20AND%20%28length%3A%5B40%20TO%20%2A%5D%29%20AND%20%28existence%3A1%29%20NOT%20%28ft_signal%3A%2A%29%20OR%20%28cc_scl_term_exp%3ASL-0191%29%20OR%20%28cc_scl_term_exp%3ASL-0204%29%20OR%20%28cc_scl_term_exp%3ASL-0039%29%20OR%20%28cc_scl_term_exp%3ASL-0091%29%20OR%20%28cc_scl_term_exp%3ASL-0209%29%20OR%20%28cc_scl_term_exp%3ASL-0173%29%29&cursor=g8xm5lh97vdkpgdfblowiyhd0uypjdfspvqjzurb&size=500
# None
# Total: 20615
# Filtered: 20615

# %%
import pandas as pd

negative_set = pd.read_csv("negative.tsv", sep="\t")
positive_set = pd.read_csv("positive.tsv", sep="\t")

print(len(positive_set))
print(len(negative_set))
print(len(negative_set[negative_set["N-term transmembrane"] == True]))
# Out:
# 2932
# 20615
# 2465
